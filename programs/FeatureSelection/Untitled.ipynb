# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('D:/DataScience-master/dataSetsAndProgML/DataSets/diabetes_data.csv')

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,cmap='viridis',linewidths=0.5,ax=ax)

# %%
data['gluscose_square'] = data['Glucose'] * data['Glucose']

# %%
data['gluscose_cube'] = data['Glucose'] **3
data['gluscose_square_root'] = np.sqrt(data['Glucose'])

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,cmap='viridis',linewidths=0.5,ax=ax)

# %%
target = 'Outcome'

# %%
X = data.drop(['Outcome'],axis=1)
y = data['Outcome'].copy()

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  gluscose_square  gluscose_cube  \
# 0                     0.627   50            21904        3241792
# 1                     0.351   31             7225         614125
# 2                     0.672   32            33489        6128487
# 3                     0.167   21             7921         704969
# 4                     2.288   33            18769        2571353
#
#    gluscose_square_root
# 0             12.165525
# 1              9.219544
# 2             13.527749
# 3              9.433981
# 4             11.704700
