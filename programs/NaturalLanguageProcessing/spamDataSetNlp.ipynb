# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem.porter import PorterStemmer
from collections import OrderedDict, Counter

# %%
import nltk

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\anaconda\lib\site-packages (1.5.0)
# Requirement already satisfied: pillow in c:\anaconda\lib\site-packages (from wordcloud) (5.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\anaconda\lib\site-packages (from wordcloud) (1.15.1)
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
data = pd.read_csv('D:/DataScience-master/dataSetsAndProgML/DataSets/spam.csv',encoding ='latin')
data.head()
# Out:
#                                                 text label
# 0  Go until jurong point, crazy.. Available only ...   ham
# 1                      Ok lar... Joking wif u oni...   ham
# 2  Free entry in 2 a wkly comp to win FA Cup fina...  spam
# 3  U dun say so early hor... U c already then say...   ham
# 4  Nah I don't think he goes to usf, he lives aro...   ham

# %%
data['label'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
data['label'].replace({"ham":0,"spam":1},inplace=True)

# %%
data.head()
# Out:
#                                                 text  label
# 0  go until jurong point, crazy.. available only ...      0
# 1                      ok lar... joking wif u oni...      0
# 2  free entry in 2 a wkly comp to win fa cup fina...      1
# 3  u dun say so early hor... u c already then say...      0
# 4  nah i don't think he goes to usf, he lives aro...      0

# %%
data['text']=data['text'].str.lower()

# %%
data['text'] = data['text'].repace('[{}]'.format.punctuation)

# %%
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in data.text: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
stop_words=list(set(stopwords.words('english')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-fac008c3877b> in <module>()
# ----> 1 stop_words=list(set(stopwords.words('english')))
#
# AttributeError: 'set' object has no attribute 'words'
