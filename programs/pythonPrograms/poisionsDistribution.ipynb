# %%
# Poision's Distribution

import numpy as np
import math


def poison(x):
    return ((3.2)**(x)*np.exp(-3.2))/math.factorial(x)

a=[]
for i in range(0,20):
    a.append(poison(i))

# %%
a
# Out:
# [0.04076220397836621,
#  0.1304390527307719,
#  0.20870248436923505,
#  0.22261598332718405,
#  0.17809278666174724,
#  0.11397938346351824,
#  0.0607890045138764,
#  0.027789259206343498,
#  0.011115703682537401,
#  0.00395225019823552,
#  0.0012647200634353665,
#  0.0003679185639084703,
#  9.811161704225874e-05,
#  2.415055188732523e-05,
#  5.520126145674339e-06,
#  1.1776269110771923e-06,
#  2.3552538221543848e-07,
#  4.433418959349431e-08,
#  7.8816337055101e-09,
#  1.327433045138543e-09]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(a)
